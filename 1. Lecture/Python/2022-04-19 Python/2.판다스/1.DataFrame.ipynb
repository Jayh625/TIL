# %% [markdown]
# ## 판다스 데이터프레임
# 판다스 데이터프레임은 다음 그림과같이 행과 열로 구성된 2차원 데이터(엑셀 데이터)를 다루는데 효과적인 자료구조입니다.

# %% [markdown]
# <img src="https://i.ibb.co/7VjmyLd/pandas-0-0.png" width="300" style="float:left" />

# %% [markdown]
# 데이터 프레임은 다음과 같이 import를 합니다.

# %%
from pandas import DataFrame
import pandas as pd

# %%
import numpy as np

# %% [markdown]
# 데이터 프레임은 크게 세 가지 방법으로 생성할 수 있습니다.
# -	딕셔너리로 데이터프레임을 생성
# -	리스트로 데이터프레임을 생성
# -	리스트와 딕셔너리로 데이터프레임을 생성
#
# #### 딕셔너리로 데이터프레임 생성

# %% [markdown]
# 우선 위 테이블을 딕셔너리로 표현해 보겠습니다. 하나의 컬럼을 딕셔너리의 키, 값 쌍으로 구성합니다. 이 때 값은 리스트 형태로 정의합니다.

# %%
딕셔너리 = {
        "x" : [10,20],
        "y" : [20,30]
}
df = DataFrame(data=딕셔너리) # DataFrame 클래스의 객체 생성 (생성자 호출)
df
# Out:
#     x   y
# 0  10  20
# 1  20  30

# %% [markdown]
# 딕셔너리 = {
#         "x": [ 10, 20  ],
#         "y": [ 20, 30  ]
# }
# df = DataFrame(data=딕셔너리)
# df

# %% [markdown]
# 데이터프레임은 생성자에서 딕셔너리를 입력받아 객체를 반환합니다. 코드를 실행하면 자동으로 맵핑된 인덱스가 함께 출력됩니다.

# %% [markdown]
# #### 리스트로 데이터프레임 생성
# 테이블의 헤더 (시가/고가/저가/종가의 1행)를 제외하고 나머지 데이터를 2차원 형태로 정의합니다.

# %%
리스트 = [
       [10,20],
       [30,40]
]
df = DataFrame(리스트)
df
# Out:
#     0   1
# 0  10  20
# 1  30  40

# %% [markdown]
# 그리고 생성자에 columns 파라미터로 헤더 정보를 전달합니다.

# %%
df.index = ['x','y']
df.columns = ['a', 'b']
df
# Out:
#     a   b
# x  10  20
# y  30  40

# %% [markdown]
# 데이터 프레임에도 다양한 속성 (인스턴스 변수)이 있는데 columns 파라미터에는 테이블 열의 제목이 들어있습니다.

# %% [markdown]
# #### 리스트와 딕셔너리를 조합
# 세 번째 방식은 두 번째와 유사하게 행 단위로 데이터를 표현하는데 이 때 데이터에 레이블을 붙여서 각 행을 하나의 딕셔너리로 표현합니다. 말로 풀어쓰면 어려운데 코드를 보면 쉽게 이해할 수 있습니다.

# %%
data = [
    {'시가': 100, '고가': 110, '저가': 90, '종가': 105}, 
    {'시가':  90, '고가': 112, '저가': 80, '종가':  95}, 
    {'시가':  80, '고가': 115, '저가': 70, '종가':  85}, 
    {'시가':  70, '고가':  80, '저가': 60, '종가':  75}, 
]
df = DataFrame(data)
df
# Out:
#     시가   고가  저가   종가
# 0  100  110  90  105
# 1   90  112  80   95
# 2   80  115  70   85
# 3   70   80  60   75

# %% [markdown]
# 데이터 프레임도 시리즈와 유사하게 인덱스를 지정할 수 있습니다.
# - 생성할 때 인덱스 추가
# - 생성 후에 인덱스 추가

# %%
z = [[10,20],
     [30,40],
]

df = DataFrame(data=z, index=['x', 'y'], columns=['a','b'])
df
# Out:
#     a   b
# x  10  20
# y  30  40

# %% [markdown]
# 세 가지 방식 모두 동일한 데이터프레임 객체를 생성합니다. 원본 데이터가 저장된 형태에 따라 적합한 데이터프레임 생성 방식을 사용하면 됩니다.

# %% [markdown]
# ----
#
# 보통 데이터는 웹에서 가져오거나 엑셀에서 저장돼 있습니다. 데이터 프레임은 엑셀이나 웹에서 값을 얻어오는 메서드를 제공하기 때문에 처음부터 데이터 프레임을 만들일은 생각보다 많지 않습니다.

# %%
data = [
        ["037730", "3R", 1510, 7.36],
        ["036360", "3SOFT", 1790, 1.65],
        ["005760", "ACTS", 1185, 1.28],
]

columns = ["종목코드", "종목명", "현재가", "등락률"]
df = DataFrame(data=data, columns=columns)
df = df.set_index('종목코드')
#df.set_index("종목코드", inplace=True)
print(df)
# Out:
#           종목명   현재가   등락률
# 종목코드
# 037730     3R  1510  7.36
# 036360  3SOFT  1790  1.65
# 005760   ACTS  1185  1.28

# %%
data = [
        ["3R", 1510, 7.36],
        ["3SOFT", 1790, 1.65],
        ["ACTS", 1185, 1.28],
]

index = ["037730", "036360", "005760"]
columns = ["종목명", "현재가", "등락률"]

df = DataFrame(data=data, index=index, columns=columns)
df.index.name = "종목코드"
print(df)
# Out:
#           종목명   현재가   등락률
# 종목코드
# 037730     3R  1510  7.36
# 036360  3SOFT  1790  1.65
# 005760   ACTS  1185  1.28

# %%
import pandas as pd

url = "https://finance.naver.com/"
dfs = pd.read_html(url)
type(dfs)
# Out:
# list

# %%
dfs[1]
# Out:
#                                     Á¾¸ñ¸í  ÇöÀç°¡    ÀüÀÏ´ëºñ   µî¶ô·ü
# 0                               ´ëÇÑÁ¦´ç¿ì    6460  »ó½Â 1,260  +24.23%
# 1                               ¿À½ºÅ×¿À´Ð    3845    »ó½Â 660  +20.72%
# 2                                 ´ëÁÖ»ê¾÷    3890    »ó½Â 590  +17.88%
# 3       »ï¼º ÀÎ¹ö½º 2X Ãµ¿¬°¡½º ¼±¹° ETN B    1165    »ó½Â 160  +15.92%
# 4                                   ½Ö¹æ¿ï    1125    »ó½Â 154  +15.86%
# 5                               ÇÑ±¹¸Æ³ÎÆ¼    9440  »ó½Â 1,290  +15.83%
# 6      TRUE ÀÎ¹ö½º 2X Ãµ¿¬°¡½º ¼±¹° ETN(H)     875    »ó½Â 110  +14.38%
# 7         ½ÅÇÑ ÀÎ¹ö½º 2X Ãµ¿¬°¡½º ¼±¹° ETN     450     »ó½Â 55  +13.92%
# 8      ½ÅÇÑ ÀÎ¹ö½º 2X Ãµ¿¬°¡½º ¼±¹° ETN(H)     290     »ó½Â 35  +13.73%
# 9                                 ±¸¿µÅ×Å©    4355    »ó½Â 485  +12.53%
# 10                                ¼­¿ï½ÄÇ°     365     »ó½Â 39  +11.96%
# 11                                ´ëÇÑÁ¦´ç    5270    »ó½Â 555  +11.77%
# 12                                    ±¤¸²    3215    »ó½Â 280   +9.54%
# 13                                  ½Å¿ø¿ì   38000  »ó½Â 3,300   +9.51%
# 14  QV ÀÎ¹ö½º ·¹¹ö¸®Áö WTI¿øÀ¯ ¼±¹° ETN(H)     120     »ó½Â 10   +9.09%

# %%
pd.read_excel("xxx")

# %%
pd.read_csv("/content/sample_data/california_housing_test.csv")
# Out:
#       longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0       -122.05     37.37                27.0       3885.0           661.0
# 1       -118.30     34.26                43.0       1510.0           310.0
# 2       -117.81     33.78                27.0       3589.0           507.0
# 3       -118.36     33.82                28.0         67.0            15.0
# 4       -119.67     36.33                19.0       1241.0           244.0
# ...         ...       ...                 ...          ...             ...
# 2995    -119.86     34.42                23.0       1450.0           642.0
# 2996    -118.14     34.06                27.0       5257.0          1082.0
# 2997    -119.70     36.30                10.0        956.0           201.0
# 2998    -117.12     34.10                40.0         96.0            14.0
# 2999    -119.63     34.42                42.0       1765.0           263.0
#
#       population  households  median_income  median_house_value
# 0         1537.0       606.0         6.6085            344700.0
# 1          809.0       277.0         3.5990            176500.0
# 2         1484.0       495.0         5.7934            270500.0
# 3           49.0        11.0         6.1359            330000.0
# 4          850.0       237.0         2.9375             81700.0
# ...          ...         ...            ...                 ...
# 2995      1258.0       607.0         1.1790            225000.0
# 2996      3496.0      1036.0         3.3906            237200.0
# 2997       693.0       220.0         2.2895             62000.0
# 2998        46.0        14.0         3.2708            162500.0
# 2999       753.0       260.0         8.5608            500001.0
#
# [3000 rows x 9 columns]

# %% [markdown]
# 온라인 강의에서 cut()이 없습니다. 내일 알려주실 수 있을까요? pandas 관련 강의를 어제 봤는데, cut 함수를 설명해주지 않았습니다.

# %%
from pandas import Series

s = Series(  [11, 15, 21, 23, 7, 7]  )
# 10 이하 - 작다
# 20 이하 - 보통
# 30 이하 - 크다
def f(x):
    if x <= 10:
        return "작다"
    elif x <= 20:
        return "보통"
    else:
        return "크다"
    return x

s.map( f )
# Out:
# 0    보통
# 1    보통
# 2    크다
# 3    크다
# 4    작다
# 5    작다
# dtype: object

# %%
s
# Out:
# 0    11
# 1    15
# 2    21
# 3    23
# 4     7
# 5     7
# dtype: int64

# %%
pd.cut(s, bins=[0, 10, 20, 30] ,labels=["작다", "보통", "크다"] )
# Out:
# 0    보통
# 1    보통
# 2    크다
# 3    크다
# 4    작다
# 5    작다
# dtype: category
# Categories (3, object): ['작다' < '보통' < '크다']

# %% [markdown]
# `혹시 replace를 for문의 기능으로 생각해도 괜찮을까요?`

# %%
s + 10
# Out:
# 0    21
# 1    25
# 2    31
# 3    33
# 4    17
# 5    17
# dtype: int64

# %% [markdown]
# ## 데이터 프레임의 구조

# %% [markdown]
# 데이터프레임의 각 컬럼은 시리즈이며 같은 인덱스를 갖는 시리즈가 모여 하나의 데이터 프레임을 구성합니다.

# %% [markdown]
# <img src="https://i.ibb.co/Xx2rtYB/pandas-0-1.png" width="600" style="float:left" />

# %% [markdown]
# 데이터 프레임은 다음과 같이 시가/고가/저가/종가 네 개의 시리즈로 구분할 수 있습니다.

# %% [markdown]
# <img src="https://i.ibb.co/x6RMmHV/pandas-0-2.png" width="600" style="float:left" />

# %% [markdown]
# 혹은 데이터프레임의 각 로우(row)는 시리즈이며 네 개의 시리즈로 구성됐다고 해석할 수 있습니다.

# %% [markdown]
# <img src="https://i.ibb.co/GpLVrCS/pandas-0-3.png" width="600" style="float:left" />

# %% [markdown]
# 이번에는 시가/고가/저가/종가의 인덱스를 갖는 네 개의 시리즈를 확인할 수 있습니다.

# %% [markdown]
# <img src="https://i.ibb.co/PGMNKH9/pandas-0-4.png" width="600" style="float:left" />

# %% [markdown]
# Q. 다음 선택된 시리즈의 인덱스는 무엇인가?

# %% [markdown]
# <img src="https://i.ibb.co/3RP6LMC/pandas-0-5.png" width="400" style="float:left" />

# %% [markdown]
# #데이터프레임과 인덱싱

# %% [markdown]
# 데이터프레임은 2차원 자료를 저장하기 때문에 로우 혹은 컬럼 단위로 데이터를 가져올 수 있습니다. 다음의 데이터프레임을 사용해서 인덱싱을 연습해 봅시다.

# %%
data = [
    {'시가': 100, '고가': 110, '저가': 90, '종가': 105}, 
    {'시가':  90, '고가': 112, '저가': 80, '종가':  95}, 
    {'시가':  80, '고가': 115, '저가': 70, '종가':  85}, 
    {'시가':  70, '고가':  80, '저가': 60, '종가':  75}, 
]

df = DataFrame(data, index=['20200615', '20200616', '20200617', '20200618'])
df
# Out:
#            시가   고가  저가   종가
# 20200615  100  110  90  105
# 20200616   90  112  80   95
# 20200617   80  115  70   85
# 20200618   70   80  60   75

# %% [markdown]
# 우선 컬럼의 데이터를 가져와 봅시다. 컬럼은 컬럼의 이름(columns)을 사용해서 선택할 수 있습니다.

# %%
df["고가"]
# Out:
# 20200615    110
# 20200616    112
# 20200617    115
# 20200618     80
# Name: 고가, dtype: int64

# %% [markdown]
# `ndarray`에서 사용해 본 것과 같이 연속하지 않은 컬럼을 선택할 수도 있습니다.

# %%
#리스트 = ["고가","종가"]
#df[리스트]
df[["고가", "종가"]]
df[df.columns[0:2]]

# %% [markdown]
# 로우 데이터는 `iloc`와 `loc`를 사용해서 값을 얻어올 수 있습니다.

# %%
print(df.iloc[0])
print('-'*30)
print(df.loc["20200615"])
# Out:
# 시가    100
# 고가    110
# 저가     90
# 종가    105
# Name: 20200615, dtype: int64
# ------------------------------
# 시가    100
# 고가    110
# 저가     90
# 종가    105
# Name: 20200615, dtype: int64

# %% [markdown]
# 당연히 연속하지 않은 여러개의 로우도 선택할 수 있습니다.

# %%
df[df.columns[0:2]]

# %% [markdown]
# 이번에는 데이터프레임에 저장된 하나의 값 (115)를 출력해 보겠습니다.

# %%
df
# Out:
#            시가   고가  저가   종가
# 20200615  100  110  90  105
# 20200616   90  112  80   95
# 20200617   80  115  70   85
# 20200618   70   80  60   75

# %%
print(df.loc['20200617'].iloc[1])
print(df.loc['20200617'].loc["고가"])
print(df.loc['20200617']["고가"])
print(df.iloc[2].iloc[1])
print(df.iloc[2].loc["고가"])
print(df.iloc[2]["고가"])

print(df.loc['20200617', '고가'])
print(df.iloc[2,1])
# Out:
# 115
# 115
# 115
# 115
# 115
# 115
# 115
# 115

# %%
df.iloc[[2,1]]
# Out:
#           시가   고가  저가  종가
# 20200617  80  115  70  85
# 20200616  90  112  80  95

# %% [markdown]
# 데이터 프레임에서는 `[ ]` 인덱싱 기호 한 번에 행과 열을 지정할 수도 있습니다.

# %%
df.iloc[[0,1],[0,1]]
# Out:
#            시가   고가
# 20200615  100  110
# 20200616   90  112

# %%
df.loc["20200615":"20200616", "시가":"고가"]
# Out:
#            시가   고가
# 20200615  100  110
# 20200616   90  112

# %%
df.iloc[0:2, 0:2]
# Out:
#            시가   고가
# 20200615  100  110
# 20200616   90  112

# %%
print(df['고가']) #시리즈화인 데이터프레임 반환
print(df[['고가']]) #<-리스트[] 같은 조건을 사용한 것

# %% [markdown]
# ### 데이터프레임 수정
# 데이터프레임에 값을 수정하거나 추가해봅시다.

# %%
data = [
    {'시가': 100, '고가': 110, '저가': 90, '종가': 105}, 
    {'시가':  90, '고가': 112, '저가': 80, '종가':  95}, 
    {'시가':  80, '고가': 115, '저가': 70, '종가':  85}, 
    {'시가':  70, '고가':  80, '저가': 60, '종가':  75}, 
]

df = DataFrame(data, index=['20200615', '20200616', '20200617', '20200618'])
df
# Out:
#            시가   고가  저가   종가
# 20200615  100  110  90  105
# 20200616   90  112  80   95
# 20200617   80  115  70   85
# 20200618   70   80  60   75

# %% [markdown]
# 데이터 프레임에 컬럼 단위로 값을 추가할 때는 컬럼의 이름과 값을 전달하면 됩니다. 만약 하나의 값을 입력한다면 컬럼 전체가 해당 값으로 채워집니다.

# %%
# Out:
#            시가   고가  저가   종가  NEW
# 20200615  100  110  90  105   10
# 20200616   90  112  80   95   10
# 20200617   80  115  70   85   10
# 20200618   70   80  60   75   10

# %% [markdown]
# 리스트 형태로 값을 전달할 수도 있습니다.

# %%
# Out:
#            시가   고가  저가   종가  NEW
# 20200615  100  110  90  105   10
# 20200616   90  112  80   95   20
# 20200617   80  115  70   85   30
# 20200618   70   80  60   75   40

# %% [markdown]
# 하나의 값을 변경할 때는 `변경할위치 = 값` 형태로 코드를 작성합니다.

# %% [markdown]
# Q. 고가와 저가의 차이를 "변동폭" 이름의 칼럼에 저장하라.

# %%
data = [
    {'시가': 100, '고가': 110, '저가': 90, '종가': 105}, 
    {'시가':  90, '고가': 112, '저가': 80, '종가':  95}, 
    {'시가':  80, '고가': 115, '저가': 70, '종가':  85}, 
    {'시가':  70, '고가':  80, '저가': 60, '종가':  75}, 
]

df = DataFrame(data, index=['20200615', '20200616', '20200617', '20200618'])
df
# Out:
#            시가   고가  저가   종가
# 20200615  100  110  90  105
# 20200616   90  112  80   95
# 20200617   80  115  70   85
# 20200618   70   80  60   75

# %% [markdown]
# 로우 단위의 데이터를 추가할 때는 `iloc` 혹은 `loc`를 사용하는 것외에 동일합니다.

# %%
data = [
    {'시가': 100, '고가': 110, '저가': 90, '종가': 105}, 
    {'시가':  90, '고가': 112, '저가': 80, '종가':  95}, 
    {'시가':  80, '고가': 115, '저가': 70, '종가':  85}, 
    {'시가':  70, '고가':  80, '저가': 60, '종가':  75}, 
]

df = DataFrame(data, index=['20200615', '20200616', '20200617', '20200618'])
df
# Out:
#            시가   고가  저가   종가
# 20200615  100  110  90  105
# 20200616   90  112  80   95
# 20200617   80  115  70   85
# 20200618   70   80  60   75

# %% [markdown]
# `20200619` 로우에 값을 추가

# %%
# Out:
#            시가   고가  저가   종가
# 20200615  100  110  90  105
# 20200616   90  112  80   95
# 20200617   80  115  70   85
# 20200618   70   80  60   75
# 20200619   10   10  10   10

# %% [markdown]
# 값을 삭제할 때는 시리즈와 동일하게 drop메서드를 사용합니다. 차이점은 데이터프레임은 2차원 형태이기 때문에 가로축 삭제인지 세로축 삭제인지를 알려줘야 합니다. `axis`는 컬럼 단위로 삭제할지 로우 단위로 삭제할지를 지정합니다. `axis=1`은 컬럼 단위로 삭제한다는 의미입니다.

# %%
df.drop('시가', axis=1)
# Out:
#            고가  저가   종가
# 20200615  110  90  105
# 20200616  112  80   95
# 20200617  115  70   85
# 20200618   80  60   75

# %% [markdown]
# 로우 단위로도 삭제할 수 있습니다. `axis`를 입력하지 않으면 0으로 간주됩니다.

# %%
# Out:
#            시가   고가  저가   종가
# 20200615  100  110  90  105
# 20200616   90  112  80   95
# 20200617   80  115  70   85

# %% [markdown]
# ## 인덱스 및 칼럼 설정하기

# %% [markdown]
# `reset_index`는 인덱스를 칼럼으로 변경합니다.

# %%
# Out:
#       index   시가   고가  저가   종가
# 0  20200615  100  110  90  105
# 1  20200616   90  112  80   95
# 2  20200617   80  115  70   85
# 3  20200618   70   80  60   75

# %% [markdown]
# `set_index`는 칼럼 이름으로 인덱스를 설정합니다.

# %% [markdown]
# ## 데이터프레임 연결하기
# 하나 이상의 데이터 프레임을 연결할 수 있습니다.

# %%
import pandas as pd
import numpy as np

df1 = pd.DataFrame(np.random.randn(4, 2), columns=['A', 'B'])
df1
# Out:
#           A         B
# 0 -0.532825 -0.799201
# 1  0.699131 -0.703095
# 2 -0.337424 -1.686015
# 3 -0.161084 -0.330879

# %%
df2 = pd.DataFrame(np.random.randn(4, 2), columns=['A', 'B'])
df2
# Out:
#           A         B
# 0  0.617020  0.151633
# 1 -0.308665  0.358633
# 2  0.802221 -0.870168
# 3  0.198000  0.282982

# %% [markdown]
# `append` 메서드로 연결한 데이터 프레임을 전달합니다

# %%
df1.append(df2)
# Out:
#           A         B
# 0  1.382102 -1.346167
# 1 -1.106819  1.331357
# 2  0.384795 -1.562648
# 3  0.064274  1.145529
# 0 -0.559248 -1.183500
# 1  0.911591 -1.103314
# 2  0.529724 -0.685318
# 3 -0.990691  0.052634

# %% [markdown]
# pd의 `concat` 함수로 연결할 데이터 프레임을 리스트로 전달합니다.

# %% [markdown]
# ### merge
# `pandas`에 정의된 `merge` 함수를 사용할 수도 있습니다.

# %%
df1 = DataFrame( np.random.randint(10, size=(2,4)), columns=["a", "b", "c", "d"])
df1['구분'] = ["가", "나"]
df1
# Out:
#    a  b  c  d 구분
# 0  3  9  1  9  가
# 1  8  0  1  1  나

# %%
df2 = DataFrame( np.random.randint(10, size=(4,4)), columns=["e", "f", "g", "h"])
df2['구분'] = ["가", "나", "다", "가"]
df2
# Out:
#    e  f  g  h 구분
# 0  3  1  7  0  가
# 1  9  3  5  6  나
# 2  9  3  6  2  다
# 3  5  9  8  5  가

# %% [markdown]
# `pd.merge(df1, df2, on="칼럼이름")` 형태로 사용합니다.

# %%
pd.merge(df1, df2, on="구분")
# Out:
#    a  b  c  d 구분  e  f  g  h
# 0  3  9  1  9  가  3  1  7  0
# 1  3  9  1  9  가  5  9  8  5
# 2  8  0  1  1  나  9  3  5  6

# %% [markdown]
# `how` 옵션을 사용하면 `join` 방식을 지정할 수 있습니다.
# - `left` / `right` / `inner`

# %% [markdown]
# #컬럼 인덱싱

# %%
data = [
    ["3R", 1510, 7.36],
    ["3SOFT", 1790, 1.65],
    ["ACTS", 1185, 1.28]
]

index = ["037730", "036360", "005760"]
columns = ["종목명", "현재가", "등락률"]
df = DataFrame(data=data, index=index, columns=columns)
print(df['현재가'])
df
# Out:
# 037730    1510
# 036360    1790
# 005760    1185
# Name: 현재가, dtype: int64
#           종목명   현재가   등락률
# 037730     3R  1510  7.36
# 036360  3SOFT  1790  1.65
# 005760   ACTS  1185  1.28

# %%
print(df.현재가)
# Out:
# 037730    1510
# 036360    1790
# 005760    1185
# Name: 현재가, dtype: int64

# %%
리스트 = ["현재가", "등락률"] # column indexing
df[리스트]
# Out:
#          현재가   등락률
# 037730  1510  7.36
# 036360  1790  1.65
# 005760  1185  1.28

# %%
print(df[["현재가", "등락률"]])
df[["현재가", "등락률"]]
# Out:
#          현재가   등락률
# 037730  1510  7.36
# 036360  1790  1.65
# 005760  1185  1.28
#          현재가   등락률
# 037730  1510  7.36
# 036360  1790  1.65
# 005760  1185  1.28

# %%
df[["현재가"]]
# Out:
#          현재가
# 037730  1510
# 036360  1790
# 005760  1185

# %% [markdown]
# #로우 인덱싱
# - loc : 인덱스를 기준으로 로우 데이터 추출
# - iloc : 행 번호를 기준으로 로우 데이터 추출

# %%
data = [
    ["3R", 1510, 7.36],
    ["3SOFT", 1790, 1.65],
    ["ACTS", 1185, 1.28]
]

index = ["037730", "036360", "005760"]
columns = ["종목명", "현재가", "등락률"]
df = DataFrame(data=data, index=index, columns=columns)
print(df)
print('-'*30)
print(df.loc["037730"])
# Out:
#           종목명   현재가   등락률
# 037730     3R  1510  7.36
# 036360  3SOFT  1790  1.65
# 005760   ACTS  1185  1.28
# ------------------------------
# 종목명      3R
# 현재가    1510
# 등락률    7.36
# Name: 037730, dtype: object

# %%
df
# Out:
#           종목명   현재가   등락률
# 037730     3R  1510  7.36
# 036360  3SOFT  1790  1.65
# 005760   ACTS  1185  1.28

# %%
print(df.iloc[0])
print('-'*30)
print(df.iloc[-1])
# Out:
# 종목명      3R
# 현재가    1510
# 등락률    7.36
# Name: 037730, dtype: object
# ------------------------------
# 종목명    ACTS
# 현재가    1185
# 등락률    1.28
# Name: 005760, dtype: object

# %%
print(df.loc[["037730", "036360"]])
print('-'*30)
print(df.iloc[[0,1]])
# Out:
#           종목명   현재가   등락률
# 037730     3R  1510  7.36
# 036360  3SOFT  1790  1.65
# ------------------------------
#           종목명   현재가   등락률
# 037730     3R  1510  7.36
# 036360  3SOFT  1790  1.65

# %% [markdown]
# #특정 값 가져오기

# %%
data = [
    ["3R", 1510, 7.36],
    ["3SOFT", 1790, 1.65],
    ["ACTS", 1185, 1.28]
]

index = ["037730", "036360", "005760"]
columns = ["종목명", "현재가", "등락률"]
df = DataFrame(data=data, index=index, columns=columns)

print(df.iloc[0])
print('-'*30)
print(df.loc['037730'])
# Out:
# 종목명      3R
# 현재가    1510
# 등락률    7.36
# Name: 037730, dtype: object
# ------------------------------
# 종목명      3R
# 현재가    1510
# 등락률    7.36
# Name: 037730, dtype: object

# %%
df
# Out:
#           종목명   현재가   등락률
# 037730     3R  1510  7.36
# 036360  3SOFT  1790  1.65
# 005760   ACTS  1185  1.28

# %%
# 행 번호로 행 선택 후 시리즈 인덱싱
print(df.iloc[0].iloc[1]) # 시리즈 행 번호
print(df.iloc[0].loc["현재가"]) # 시리즈 인덱스
print(df.iloc[0]["현재가"]) # 시리즈 인덱스
print('-'*5)
# 인덱스로 행 선택 후 시리즈 인덱싱
print(df.loc["037730"].iloc[1]) # 시리즈 행 번호
print(df.loc["037730"].loc["현재가"]) # 시리즈 인덱스
print(df.loc["037730"]["현재가"]) # 시리즈 인덱스
# Out:
# 1510
# 1510
# 1510
# -----
# 1510
# 1510
# 1510

# %%
print(df.loc["037730", "현재가"]) # loc[로우 인덱스, 컬럼명]
print(df.iloc[0,1]) #iloc[행번호, 열번호]
# Out:
# 1510
# 1510

# %%
# 컬럼을 먼저 인덱싱한 후 다시 로우를 선택
print(df["현재가"].iloc[0])
print(df["현재가"].loc["037730"])
print(df["현재가"]["037730"])
# Out:
# 1510
# 1510
# 1510

# %% [markdown]
# 가독성이나 실행 속도 측면에서는
# - df.loc[행,열]
# - df.iloc[행번호, 열번호]
#
# 방식이 더 좋음

# %% [markdown]
# #특정범위 가져오기

# %%
data = [
        ["3R", 1510, 7.36],
        ["3SOFT", 1790, 1.65],
        ["ACTS", 1185, 1.28]
]
 
index = ["037730", "036360", "005760"]
columns = ["종목명", "현재가", "등락률"]
df = DataFrame(data=data, index=index, columns=columns)
 
print(df.loc[["037730", "036360"]])
print(df.iloc[[0, 1]])
# Out:
#           종목명   현재가   등락률
# 037730     3R  1510  7.36
# 036360  3SOFT  1790  1.65
#           종목명   현재가   등락률
# 037730     3R  1510  7.36
# 036360  3SOFT  1790  1.65

# %%
df
# Out:
#           종목명   현재가   등락률
# 037730     3R  1510  7.36
# 036360  3SOFT  1790  1.65
# 005760   ACTS  1185  1.28

# %%
# 필요한 컬럼들만 다시 인덱싱
df = df.loc[["037730", "036360"]] # 두 개의 행을 선택해서 df 변수에 업데이트, df가 슬라이싱한 값을 가리키므로 기존에 바인딩하고 있던 값은 제거됨
df = df[["종목명", "현재가"]] # 종목명과 현재가 컬럼을 슬라이싱하고 그 결과를 df 변수가 가리킵니다
df
# Out:
#           종목명   현재가
# 037730     3R  1510
# 036360  3SOFT  1790

# %%
# 한번에 슬라이싱 하는 방법이 실행 속도도 빠르고 성능 저하도 없음
print(df.loc[["037730", "036360"], ["종목명", "현재가"]])
print('-'*30)
print(df.iloc[[0,1], [0,1]])
# Out:
#           종목명   현재가
# 037730     3R  1510
# 036360  3SOFT  1790
# ------------------------------
#           종목명   현재가
# 037730     3R  1510
# 036360  3SOFT  1790

# %% [markdown]
# #데이터프레임 필터링

# %%
data = [
        ["3R", 1510, 7.36],
        ["3SOFT", 1790, 1.65],
        ["ACTS", 1185, 1.28]
]

index = ["037730", "036360", "005760"]
columns = ["종목명", "현재가", "등락률"]
df = DataFrame(data=data, index=index, columns=columns)
cond = df['현재가'] >= 1400
print(df.loc[cond]) # 현재가 시리즈의 값중 1400 이상인 값들 출력
# Out:
#           종목명   현재가   등락률
# 037730     3R  1510  7.36
# 036360  3SOFT  1790  1.65

# %%
df
# Out:
#           종목명   현재가   등락률
# 037730     3R  1510  7.36
# 036360  3SOFT  1790  1.65
# 005760   ACTS  1185  1.28

# %%
cond = df['현재가'] >= 1400
print(df.loc[cond]["현재가"])
print('-'*30)
print(df.loc[cond, "현재가"]) # 한번에 조건을 만족하는 현재가 컬럼을 선택, 실행속도 빠름
# Out:
# 037730    1510
# 036360    1790
# Name: 현재가, dtype: int64
# ------------------------------
# 037730    1510
# 036360    1790
# Name: 현재가, dtype: int64

# %%
cond = (df['현재가'] >= 1400) & (df['현재가'] < 1700) # 괄호로 조건을 구분해야함
print(df.loc[cond])
# Out:
#        종목명   현재가   등락률
# 037730  3R  1510  7.36

# %%
cond = (df['현재가'] >= 1400) & (df['현재가'] < 1700)
print(df.loc[~cond])
# Out:
#           종목명   현재가   등락률
# 036360  3SOFT  1790  1.65
# 005760   ACTS  1185  1.28
