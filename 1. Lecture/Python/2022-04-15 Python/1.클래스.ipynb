# %% [markdown]
# # 복습
# ### 자료구조
# 데이터를 효과적으로 관리하려고
#
# ### 반복문
# 코드 사용 효과적으로 사용하기 위해서
#
# ### 함수
# 재사용성을 높이기위해
# 유지보수를 용이하게 하기위해

# %% [markdown]
# # 파이썬 클래스
# 최대한(?) 간단히 클래스를 설명해보겠습니다. 기본적인 내용만 설명하기 때문에 파이썬 입문서를 한 권 추가로 읽어 보실 것을 추천드립니다.

# %% [markdown]
# ## 클래스란?

# %% [markdown]
# 클래스는 함수와 같은 의도로 코드를 정리하기 위해 사용합니다. 함수 보다 한 발 더 나아가 관련된 함수와 변수를 하나로 묶어서 정리할 수 있습니다. 관련 있는 통계학/경제학/정치학을 사회과학이라는 보다 큰 카테고리로 묶는 것과 같습니다.
# <img src="https://i.ibb.co/2MgSYz7/class-0.png" width="600" style="float:left" />

# %% [markdown]
# 클래스는 `class` 키워드로 정의(정리) 할 수 있습니다. 함수와 같은 원리로 정의 자체는 아무런 동작을 수행하지 않습니다. 클래스내에 정의된 함수를 특별히 <b>메서드(method)</b>라고 부릅니다. 이 때 함수의 첫 번째 파라미터로 `self`를 추가해야 합니다.

# %%
# 함수 안의 함수
def f():
    def g():
        return 3
    return g()
f()
# Out:
# 3

# %%
def 통계학 ():
    print("통계학")

def 경제학 ():
    print("경제학")

def 정치학 ():
    print("정치학")

# %%
# class 관련있는 함수를 큰 카테고리 class로 묶음
# 함수의 첫번째 파라미터로 self를 넣어준다
class 사회과학:
  def 통계학 (self):
    print("통계학")

  def 경제학 (self):
    print("경제학")

  def 정치학 (self):
    print("정치학")

# %% [markdown]
# 정의된 클래스는 이를 호출해서 생성할 수 있습니다. 클래스로 정의하면 사용하는 방법이 조금 달라지는것 뿐입니다.

# %%
변수 = 사회과학() 
# 사회과학 오브젝트를 만들고 변수가 그걸 가리키고 있다
# 인스턴스 오브젝트 : 메모리 공간을 독립적으로 사용한다
print(type(변수))
# Out:
# <class '__main__.사회과학'>

# %% [markdown]
# 클래스를 생성한 결과를 인스턴스/오브젝트/객체 라고 부릅니다. 위 코드는 사회과학 클래스를 생성해서 반환된 사회과학 객체를 변수에 바인딩하는 겁니다. 붕어빵처럼 얼마든지 여러개의 객체를 찍어낼 수 있습니다.

# %%
변수1 = 사회과학()
변수2 = 사회과학()

# %% [markdown]
# 메모리에는 다음과 같이 클래스와 객체가 저장됩니다. 우선 설계도인 "사회과학 클래스"가 메모리에 저장됩니다. 그리고 `변수1 = 사회과학()` 코드가 실행되면 클래스를 복사해서 객체를 메모리의 새로운 공간에 복사하고 이를 변수 1이 가리킵니다. `변수2 = 사회과학()` 코드가 실행되면 동일한 과정이 반복됩니다. 여기서 중요한 점은 <b> 별도의 메모리에 두 객체가 저장</b>된다는 것입니다.

# %% [markdown]
# <img src="https://i.ibb.co/HDPzP9D/class-1.png" width="400" style="float:left" />

# %% [markdown]
# 클래스에 정의된 메서드 (함수)는 객체를 통해 호출할 수 있습니다. 위 그림을 참고하면 변수1 객체에는 사회과학 클래스로부터 복사된 세 개의 함수가 정의돼 있습니다. 이를 호출하는 코드는 다음과 같습니다.

# %%
변수1 = 사회과학()

사회과학.통계학(변수1) # 사회과학 안에 정의된 통계학 method 호출
사회과학.경제학(변수1)
사회과학.정치학(변수1)
# Out:
# 통계학
# 경제학
# 정치학

# %% [markdown]
# 함수와 동일하게 메서드의 정의에 따라 메서드를 호출하는 방법이 다릅니다.

# %%
class 수업시간:
    def 예제1(self):
        return "어려워요"

    def 예제2(self, 값):
        print("입력:", 값)

# %%
변수 = 수업시간() # 객체를 생성
print(수업시간.예제1(변수))
수업시간.예제2(변수,10)
# Out:
# 어려워요
# 입력: 10

# %% [markdown]
# ###### 연습 문제
# 다음의 함수를 "예의바른학생"이라는 이름의 클래스로 정리해 봅시다.

# %%
def 첫인사(이름):
    print("안녕하세요")
    print("반갑습니다")
    print(f"내이름은 {무지}!")
    
def 작별인사():
    print("안녕히가세요")
    print("다음에 뵙겠습니다")

# %%
class 예의바른학생:
  def 첫인사(self, 이름):
    print("안녕하세요")
    print("반갑습니다")
    print(f"내이름은 {이름}!")
    
  def 작별인사(self):
    print("안녕히가세요")
    print("다음에 뵙겠습니다")

# %% [markdown]
# 예의바른학생에 정의된 `첫인사`, `작별인사` 메서드를 호출하라.

# %%
객체 = 예의바른학생()

예의바른학생.첫인사(객체, "무지")
예의바른학생.작별인사(객체)
# Out:
# 안녕하세요
# 반갑습니다
# 내이름은 무지!
# 안녕히가세요
# 다음에 뵙겠습니다

# %%
#예의바른학생.첫인사(객체, "무지")
객체.첫인사("무지")
#예의바른학생.작별인사(객체)
객체.작별인사()
# 파이썬에서는 객체.method()가 가능하다
# Out:
# 안녕하세요
# 반갑습니다
# 내이름은 무지!
# 안녕히가세요
# 다음에 뵙겠습니다

# %%
class 마린:
  def 공격하기(self):
    print("두두두두")

m = 마린()
m.공격하기()
#마린.공격하기(m)
# Out:
# 두두두두

# %%
class A:
  def run(self):
    print("a")
class B:  
  def run(self):
    print("b")
o1 = A()
o2 = B()
o3 = A() # 변수가 달라서 메모리의 다른 공간에 저장된다 
o1.run()
o2.run()
# Out:
# a
# b

# %% [markdown]
# ## self의 이해

# %% [markdown]
# 메서드에 추가하는 첫 번째 파라미터의 이름입니다. 변수처럼 `self` 대신 다른 이름을 넣어도 정상 동작합니다.

# %%
class 사회과학:
    def 통계학 (ㅇㅇㅇ):
        print("통계학")
        
객체 = 사회과학()
사회과학.통계학(객체)
# Out:
# 통계학

# %% [markdown]
# 하지만 관습적으로 `self`라는 키워드를 사용합니다. 함수의 정의만 보고 클래스 안의 함수인 것을 알아챌 수 있도록 우리도 `self`를 사용하는 것이죠.

# %% [markdown]
# 파이썬은 클래스에 정의된 메서드를 `객체.메서드()` 형태로 쉽게 사용할 수 있는 편의 기능을 제공합니다.

# %%
객체 = 사회과학()
객체.통계학()    # 사회과학.통계학(객체)와 동일한 동작
# Out:
# 통계학

# %% [markdown]
# 객체는 일반적으로 메모리를 가리키는 `변수`와 함께 `.` 그리고 `메서드 이름`을 나열합니다.
# - `객체.메서드명()`

# %% [markdown]
# ###### 연습 문제
# `예의바른학생` 클래스를 메서드 편의 기능을 활용해서 간단히 <span style="color:red">호출</span>하라.

# %%
class 예의바른학생:
  def 첫인사(self, 이름):
    print("안녕하세요")
    print("반갑습니다")
    print(f"내이름은 {이름}!")
    
  def 작별인사(self):
    print("안녕히가세요")
    print("다음에 뵙겠습니다")

# %%
import numpy as np

a = np.array([10, 20])
print(type(a))
a.all()
# numpy.ndarray.all(a)
# Out:
# <class 'numpy.ndarray'>
# True

# %%
import pandas as pd

df = pd.DataFrame()
print(type(df))
#df.combine()
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %% [markdown]
# ## 인스턴스 변수

# %% [markdown]
# 클래스는 함수 + 데이터를 모아 놓은것

# %% [markdown]
# 함수의 지역변수는 함수의 호출 종료와 함께 제거됩니다.

# %%
def 이름입력(name):
    이름 = name
    
def 출력하기():
    print(이름)
    
이름입력("유종훈")
출력하기()

# %% [markdown]
# 인스턴스의 함수 간에는 변수(값)을 공유할 수 있습니다. `self` 변수라고도 불리는데 `self.변수`와 같은 형태로 작성하면 일반 변수와 달리 그 값이 함수의 종료 이후에도 유지됩니다.

# %%
class 사람:
    def 이름입력 (self, 이름):
        self.이름 = 이름

    def 출력하기 (self):
        print(self.이름)

첫째 = 사람()
첫째.이름입력("유종훈") # self = 첫째, 첫째 안에 이름 출력
첫째.출력하기() # 함수 종료후 self.이름에 저장이 되어서 출력이됨
# 주기적으로 referencing 되지 않는 값은 삭제
# Out:
# 유종훈

# %% [markdown]
# 출력하기 메서드 안에서 `self.이름`은 `이름입력` 함수에서 저장한 값입니다. 클래스에서는 `self.이름`과 `이름` 두 가지는 변수명이 비슷하지만 전혀 특성이 다른 변수입니다. 만약 일반 변수 (self가 없는)에 값을 저장했다면 `이름입력` 함수가 종료되면서 제거되기 때문에, 출력하기에서 변수를 사용할 수 없습니다.

# %%
class 사람:
    def 이름입력 (self, 이름):
        너의이름은 = 이름

    def 출력하기 (self):
        print(너의이름은)

첫째 = 사람()
첫째.이름입력("유종훈")
첫째.출력하기()

# %% [markdown]
# 그림과 함께 이해해 봅시다.
# - 사람 객체를 생성하면 메모리 어딘가에 저장되고 첫재라는 이름표를 붙입니다. 첫째 안에는 이름하기(), 출력하기() 메서드가 복사됩니다.
# - `이름입력` 메서드를 호출하면 내부적으로 `self.이름` 변수에 `유종훈`이 저장됩니다. 인스턴스 변수를 사용하면 첫째가 저장된 메모리 공간에  이름을 추가적으로 저장합니다.
# - `출력하기` 메서드를 호출하면 `self.이름`을 가져와서 화면에 출력합니다. 이때 `self`는 메서드가 포함된 객체를 의미하여, `self.이름`은 현재 첫째의 메모리안에 있는 이름이라는 변수를 가리킵니다.

# %% [markdown]
# <img src="https://i.ibb.co/SsjQHdd/class-2.png" width="700" style="float:left" />

# %% [markdown]
# 인스턴스에 저장된 변수는 객체를 사용해서도 가져올 수 있습니다. 첫째 객체 안에 있는 이름이라는 변수에 저장된 값을 가져오니 "유종훈" 이라는 문자열이 출력됩니다.

# %%
class 사람:
    def 이름입력 (self, 이름):
        self.이름 = 이름

    def 출력하기 (self):
        print(self.이름)

첫째 = 사람()
첫째.이름입력("유종훈")

# %%
print(첫째.이름)
# Out:
# 유종훈

# %% [markdown]
# 객체의 외부에서 값을 저장 및 변경할 수 있습니다.

# %%
print(첫째.이름)
첫째.이름 = "철수"
print(첫째.이름)

# %% [markdown]
# 객체는 붕어빵찍듯이 여러 개를 생성할 수있습니다. 코드를 정리해서 재사용성을 높이기 위해서 함수와 클래스를 사용한다고 했었죠? 여기에서 클래스의 장점을 확인할 수 있습니다.

# %%
첫째 = 사람()
첫째.이름입력("유종훈")
print(첫째.이름)

둘째 = 사람()
둘째.이름입력("유정현")
둘째.출력하기()

# %% [markdown]
# 메모리에서 이를 표현해 봅시다. 첫째와 둘째는 각각 독립적인 공간에 생성이되고 이를 각각의 변수가 가리킵니다. 첫째와 둘째 각각에 `이름입력`, `출력하기` 메서드가 복사됩니다. `이름입력` 메서드를 호출할 때 전달한 파라미터 값이 인스턴스가 저장된 공간에 저장됩니다. 중요한 점은 인턴스 간에는 서로 영향을 받지 않는다는 것입니다.

# %% [markdown]
# <img src="https://i.ibb.co/thvWjLv/class-3.png" width="300" style="float:left" />

# %% [markdown]
# ## 초기화자 (Initializer)
# 다음의 사람 클래스를 참고하면 클래스를 생성하는 코드가 반복됩니다.

# %% [markdown]
# ```python
# 엄마 = 사람()
# 엄마.출생("이월순", "640423", "여")
# 엄마.정보출력()
#
# 아빠 = 사람()
# 아빠.출생("유희준", "590125", "남")
# 아빠.정보출력()
# ```

# %% [markdown]
# 초기화자를 사용하면 클래스를 생성할 때 값을 함께 입력할 수 있습니다. `__init__`이라는 이름을 갖는 메서드를 초기화자라고 부르는데 이는 특별한 기능을 갖습니다. 초기화자가 정의되면 파이썬 인터프리터는 객체가 생성될 때 자동으로 `__init__` 메서드를 호출해 줍니다. 아래의 코드에서 `__init__` 함수를 호출하지 않았지만 파이썬 인터프리터가 자동으로 호출하여 콘솔창에 "자동호출됨"이라는 문자열이 출력됩니다.

# %%
class 사람 :
    def __init__(self):
        print("자동호출됨")
        
사람() # __init__ : 객체가 만들어질때 자동 실행됨 initializer
# Out:
# 자동호출됨

# %%
class 사람 :
    def __init__(self, 이름):
        print("자동호출됨", 이름)
        
객체 = 사람(이름="종훈")
# Out:
# 자동호출됨 종훈

# %% [markdown]
# 초기화자에 입력값을 추가하면 객체를 생성할 때 파라미터를 반드시 전달해야 합니다. `__init__` 메서드도 함수의 일종이기 때문에 사용 원리는 함수와 같습니다.

# %%
class 사람 :
    

아빠 = 사람("유희준")
print(아빠.이름)

# %% [markdown]
# 다음과 같이 두 개의 값을 입력받도록 정의하면 두 개의 파라미터를 전달해야 합니다.
# 참고로 pass는 기능을 구현하지 않고 문법 에러를 회피하기 위해 사용하는 키워드입니다.

# %%
class 사람 :
    def __init__(self, 이름, 나이):
        pass

객체 = 사람("유희준", 60)

# %%
class 계좌:
  발급계좌수 = 0 # 클래스 변수
  def __init__(self, 이름, 입금액):
    self.이름 = 이름
    self.입금액 = 입금액 
    계좌.발급계좌수 = 계좌.발급계좌수 + 1
    print(계좌.발급계좌수)
a = 계좌("유종훈", 100000)
b = 계좌("유정현", 100)
print(a.이름)
print(b.이름)
# Out:
# 1
# 2
# 유종훈
# 유정현

# %%
class 사람:
  변수 = 10

# %%
객체1 = 사람()
객체2 = 사람()

# %%
객체1.변수 = 30
객체1.변수
# Out:
# 30

# %%
객체2.변수
# Out:
# 10

# %% [markdown]
# 기본적으로 파이썬은 연산자 오버로딩을 지원하지 않는다

# %%
class 사람:
    수 = 0
    def __init__(self):
      사람.수 = 사람.수 + 1

a = 사람()
b = 사람()
a.수
# Out:
# 2

# %%
class 사람:    
    def __repr__(self):
        return "ㅋㅋㅋ"

객체 = 사람()
print(객체)
# Out:
# ㅋㅋㅋ

# %%
# __init__ : 객체가 만들어지고 메모리에 공간확보, 자동적으로 실행되는 메소드, 
# 파라미터를 지정하면 객체를 생성할때 같은 파라미터를 집어넣어야 한다

class 계좌:
  발급계좌수 = 0 # 클래스 변수
  def __init__(self, 이름, 입금액): 
    self.이름 = 이름
    self.입금액 = 입금액 
    계좌.발급계좌수 = 계좌.발급계좌수 + 1
    print(계좌.발급계좌수)
  
  def __repr__(self): 
    return f"{self.이름} {self.입금액}"

a = 계좌("유종훈", 100000)
b = 계좌("유정현", 100)
print(a.이름)
print(b.이름)
# Out:
# 1
# 2
# 유종훈
# 유정현
